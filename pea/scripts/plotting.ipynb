# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

# Set some defaults
plt.rc("axes.spines", top=False, right=False)
sns.set_theme(context="paper", font_scale=1.2)
sns.set_style("ticks")

# %config InlineBackend.figure_format = "retina"

# %%
df = pd.read_csv("../data/Exp4data.csv")
df.head()
# Out:
#    sub  day  perturb  blur       stl
# 0    1    1       -4     1  0.197034
# 1    1    1       16     1 -1.629565
# 2    1    1       64     1 -4.615944
# 3    1    1      -64     2  3.952576
# 4    1    1      -16     2 -1.328925

# %%
sns.relplot(data=df, kind="line", x="perturb", y="stl", hue="blur", aspect=2)
plt.show()
# Out:
# /Users/hyosubkim/opt/anaconda3/envs/ige-ege/lib/python3.11/site-packages/seaborn/axisgrid.py:123: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
